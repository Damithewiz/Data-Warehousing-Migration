# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('ecommerce_dataset_updated.csv')

# %%
df.head(10)
# Out:
#     User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 0  337c166f  f414122f-e          Sports        36.53            15
# 1  d38a19bf  fde50f9c-5        Clothing       232.79            20
# 2  d7f5f0b0  0d96fc90-3          Sports       317.02            25
# 3  395d4994  964fc44b-d            Toys       173.19            25
# 4  a83c145c  d70e2fc6-e          Beauty       244.80            20
# 5  3fdcdae8  0816ee12-5           Books       241.86            50
# 6  12772337  d41e0b55-c            Toys        76.91             5
# 7  9f0194af  83b7dc04-5          Sports       213.23            20
# 8  7a8559d8  87c9c896-1          Sports       379.81             5
# 9  8911f0d1  31308875-b  Home & Kitchen       415.36            50
#
#    Final_Price(Rs.) Payment_Method Purchase_Date
# 0             31.05    Net Banking    12-11-2024
# 1            186.23    Net Banking    09-02-2024
# 2            237.76    Credit Card    01-09-2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           3660 non-null   object
#  1   Product_ID        3660 non-null   object
#  2   Category          3660 non-null   object
#  3   Price (Rs.)       3660 non-null   float64
#  4   Discount (%)      3660 non-null   int64
#  5   Final_Price(Rs.)  3660 non-null   float64
#  6   Payment_Method    3660 non-null   object
#  7   Purchase_Date     3660 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 228.9+ KB

# %%
df.describe(include = 'all')
# Out:
#          User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# count       3660        3660            3660  3660.000000   3660.000000
# unique      3660        3660               7          NaN           NaN
# top     337c166f  f414122f-e  Home & Kitchen          NaN           NaN
# freq           1           1             549          NaN           NaN
# mean         NaN         NaN             NaN   254.800675     18.825137
# std          NaN         NaN             NaN   141.682621     14.731338
# min          NaN         NaN             NaN    10.090000      0.000000
# 25%          NaN         NaN             NaN   134.012500      5.000000
# 50%          NaN         NaN             NaN   253.845000     15.000000
# 75%          NaN         NaN             NaN   377.595000     25.000000
# max          NaN         NaN             NaN   499.960000     50.000000
#
#         Final_Price(Rs.) Payment_Method Purchase_Date
# ...

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Product_ID          0
# Category            0
# Price (Rs.)         0
# Discount (%)        0
# Final_Price(Rs.)    0
# Payment_Method      0
# Purchase_Date       0
# dtype: int64

# %%
df.to_csv("ecommerce_dataset.csv", index=False)

# %%
df.shape
# Out:
# (3660, 8)

# %%
# conda install -c anaconda psycopg2

# %%
# conda update -n base -c defaults conda

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:damithewiz%4013@localhost:5432/ecommerce_dw")

df = pd.read_csv("ecommerce_dataset.csv")
df.to_sql("stg_ecommerce_sales", engine, if_exists="replace", index=False)
# Out:
# 660
